# %%
import pandas as pd

# %% [markdown]
# ## CREATE A DATAFRAME FROM A  DICTIONARY

# %%
tempDics= {
# Out:
#   Cell In[4], line 1
#     tempDics= {
#                ^
# _IncompleteInputError: incomplete input

# %%
tempDict= {
"name":[ "govinda", "Krishna", "hari" ],
    "Designation": ["backend developer " , "Ai developer" , "devops engineer"],
    "salary" : [15000,25000,35000]   
    
    
}

# %%
dictDf=pd.DataFrame.from_dict(tempDict)

# %%
dictDf
# Out:
#       name         Designation  salary
# 0  govinda  backend developer    15000
# 1  Krishna        Ai developer   25000
# 2     hari     devops engineer   35000

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.dtypes
#
# NameError: name 'df' is not defined

# %%
tempDict.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 tempDict.columns
#
# AttributeError: 'dict' object has no attribute 'columns'
